# %%
# import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import time
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# #### read in train/test sets

# %%
df_train_sets = pd.read_pickle('ebw_poc_train_sample_expt3_with_shf_aligned_h1.pkl')
df_test_sets  = pd.read_pickle('ebw_poc_test_sample_expt3_with_shf_aligned_h1.pkl')

# %%
mask_train = (df_train_sets.index.get_level_values(3) <= 26)
mask_test = (df_test_sets.index.get_level_values(3) <= 26)
df_train_sets = df_train_sets.loc[mask_train]
df_test_sets = df_test_sets.loc[mask_test]

# %% [markdown]
# #### read in GBM model

# %%
file_gbm='best_est_gbm_h1_expt3_with_aligned_shf.pkl'
with open(file_gbm, 'rb') as file:
    best_estimators_gbm = pickle.load(file)

# %% [markdown]
# #### plot learning curve

# %%
id_cols = list(df_train_sets.index)
target_cols = ['censoring_flg_mod', 'target']
cat_cols = ['market_name']
feature_cols = list(set(df_train_sets.columns) - set(target_cols))
num_cols = list(set(feature_cols) -set(cat_cols))

# %%
split_number = 5
random_state = 1000
weeks_range = range(27)

# %%
best_estimators_gbm[0]
# Out:
# as_concordance_index_ipcw_scorer(estimator=GradientBoostingSurvivalAnalysis(max_depth=8,
#                                                                             max_features='sqrt',
#                                                                             min_samples_leaf=16,
#                                                                             min_samples_split=8,
#                                                                             n_estimators=200,
#                                                                             subsample=0.9))

# %%
from sklearn.model_selection import learning_curve, cross_val_score
from sksurv.metrics import concordance_index_ipcw, as_concordance_index_ipcw_scorer, cumulative_dynamic_auc, as_cumulative_dynamic_auc_scorer

def concordance_scorer_ipcw(estimator, X, y):
    return estimator.score(X, y)

# %%
# plot learning curve
for wk in weeks_range:
    start = time.perf_counter()


    X_train = df_train_sets[df_train_sets.index.get_level_values(3) == wk][feature_cols]
    X_train = pd.get_dummies(X_train, columns=['market_name'])
    # X_train[num_cols] = StandardScaler().fit_transform(X_train[num_cols])
    y_train = df_train_sets[df_train_sets.index.get_level_values(3) == wk][target_cols].to_records(index=False)

    lc = learning_curve(best_estimators_gbm[wk], X_train, y_train, cv=10, scoring=concordance_scorer_ipcw)
    break

# %%
plt.plot(lc[0], np.mean(lc[1], axis=1))
plt.plot(lc[0], np.mean(lc[2], axis=1))

# %% [markdown]
# #### error analysis

# %% [markdown]
# ##### error analysis by spins-to-burn quintile

# %%
scores_train = {}
scores_test = {}

for wk in weeks_range:
    start = time.perf_counter()

    estimator = best_estimators_gbm[wk]

    X_train = df_train_sets[df_train_sets.index.get_level_values(3) == wk][feature_cols]
    drop_cols = X_train.columns[X_train.isna().any()].tolist()
    X_train.drop(drop_cols, axis=1, inplace=True)
    X_train = pd.get_dummies(X_train, columns=['market_name'])
    y_train = df_train_sets[df_train_sets.index.get_level_values(3) == wk][target_cols].to_records(index=False)
    # scores_train[wk] = estimator.score(X_train[estimator.estimator.feature_names_in_], y_train)
    scores_train[wk] = cross_val_score(estimator, X_train, y_train, cv=5, scoring=concordance_scorer_ipcw)

    X_test = df_test_sets[df_test_sets.index.get_level_values(3) == wk][feature_cols]
    X_test = pd.get_dummies(X_test, columns=['market_name'])
    missing_cols = list(set(estimator.estimator.feature_names_in_) - set(X_test.columns))
    print(missing_cols)
    for col in missing_cols:
        X_test[col] = 0
    test_idx = X_test[estimator.estimator.feature_names_in_].dropna().index
    y_test = df_test_sets[df_test_sets.index.get_level_values(3) == wk].loc[test_idx, target_cols].to_records(index=False)

    scores_test[wk] = estimator.score(X_test[estimator.estimator.feature_names_in_].loc[test_idx], y_test)
# Out:
# /home/ubuntu/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/ubuntu/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/home/ubuntu/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/sklearn/metrics/_scorer.py", line 105, in __call__
#     score = scorer(estimator, *args, **kwargs)
#   File "/tmp/ipykernel_14155/3449495074.py", line 5, in concordance_scorer_ipcw
#     return estimator.score(X, y)
#   File "/home/ubuntu/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/sksurv/metrics.py", line 791, in score
#     score = self._score_func(
#   File "/home/ubuntu/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/sksurv/metrics.py", line 318, in concordance_index_ipcw
#     test_event, test_time = check_y_survival(survival_test)
#   File "/home/ubuntu/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/sksurv/util.py", line 149, in check_y_survival
#     raise ValueError('all samples are censored')
# ValueError: all samples are censored
#
#   warnings.warn(
# []
# /home/ubuntu/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/ubuntu/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/home/ubuntu/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/sklearn/metrics/_scorer.py", line 105, in __call__
#     score = scorer(estimator, *args, **kwargs)
#   File "/tmp/ipykernel_14155/3449495074.py", line 5, in concordance_scorer_ipcw
#     return estimator.score(X, y)
#   File "/home/ubuntu/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/sksurv/metrics.py", line 791, in score
#     score = self._score_func(
#   File "/home/ubuntu/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/sksurv/metrics.py", line 318, in concordance_index_ipcw
#     test_event, test_time = check_y_survival(survival_test)
#   File "/home/ubuntu/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/sksurv/util.py", line 149, in check_y_survival
#     raise ValueError('all samples are censored')
# ValueError: all samples are censored
#
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_14155/3935677201.py in <cell line: 4>()
#      13     y_train = df_train_sets[df_train_sets.index.get_level_values(3) == wk][target_cols].to_records(index=False)
#      14     # scores_train[wk] = estimator.score(X_train[estimator.estimator.feature_names_in_], y_train)
# ---> 15     scores_train[wk] = cross_val_score(estimator, X_train, y_train, cv=5, scoring=concordance_scorer_ipcw)
#      16
#      17     X_test = df_test_sets[df_test_sets.index.get_level_values(3) == wk][feature_cols]
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     507     scorer = check_scoring(estimator, scoring=scoring)
#     508
# --> 509     cv_results = cross_validate(
#     510         estimator=estimator,
#     511         X=X,
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     265     # independent, and that it is pickle-able.
#     266     parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 267     results = parallel(
#     268         delayed(_fit_and_score)(
#     269             clone(estimator),
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1086                 self._iterating = self._original_iterator is not None
#    1087
# -> 1088             while self.dispatch_one_batch(iterator):
#    1089                 pass
#    1090
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     899                 return False
#     900             else:
# --> 901                 self._dispatch(tasks)
#     902                 return True
#     903
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     817         with self._lock:
#     818             job_idx = len(self._jobs)
# --> 819             job = self._backend.apply_async(batch, callback=cb)
#     820             # A job can complete so quickly than its callback is
#     821             # called before we get here, causing self._jobs to
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     595         # Don't delay the application, to avoid keeping the input
#     596         # arguments in memory
# --> 597         self.results = batch()
#     598
#     599     def get(self):
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     286         # change the default number of processes to -1
#     287         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288             return [func(*args, **kwargs)
#     289                     for func, args, kwargs in self.items]
#     290
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     286         # change the default number of processes to -1
#     287         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288             return [func(*args, **kwargs)
#     289                     for func, args, kwargs in self.items]
#     290
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/sklearn/utils/fixes.py in __call__(self, *args, **kwargs)
#     214     def __call__(self, *args, **kwargs):
#     215         with config_context(**self.config):
# --> 216             return self.function(*args, **kwargs)
#     217
#     218
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     678             estimator.fit(X_train, **fit_params)
#     679         else:
# --> 680             estimator.fit(X_train, y_train, **fit_params)
#     681
#     682     except Exception:
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/sksurv/metrics.py in fit(self, X, y, **fit_params)
#     764     def fit(self, X, y, **fit_params):
#     765         self._train_y = numpy.array(y, copy=True)
# --> 766         self.estimator_ = self.estimator.fit(X, y, **fit_params)
#     767         return self
#     768
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/sksurv/ensemble/boosting.py in fit(self, X, y, sample_weight, monitor)
#     936             Returns self.
#     937         """
# --> 938         X = self._validate_data(
#     939             X, ensure_min_samples=2, order='C', accept_sparse=['csr', 'csc', 'coo'], dtype=DTYPE,
#     940         )
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     564             raise ValueError("Validation should be done on X, y or both.")
#     565         elif not no_val_X and no_val_y:
# --> 566             X = check_array(X, **check_params)
#     567             out = X
#     568         elif no_val_X and not no_val_y:
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     744                     array = array.astype(dtype, casting="unsafe", copy=False)
#     745                 else:
# --> 746                     array = np.asarray(array, order=order, dtype=dtype)
#     747             except ComplexWarning as complex_warning:
#     748                 raise ValueError(
#
# KeyboardInterrupt:

# %%
plt.plot(scores_train.keys(), [np.max(scores_train[ky]) for ky in scores_train.keys()], linewidth=2, marker='o')
plt.plot(scores_test.keys(), [scores_test[ky] for ky in scores_test.keys()], linewidth=2, marker='^')

# %% [markdown]
# #### predicted risk scores

# %%
preds_train = {}
surv_fn_train = {}
preds_test = {}
surv_fn_test = {}

for wk in weeks_range:
    start = time.perf_counter()

    estimator = best_estimators_gbm[wk]

    X_train = df_train_sets[df_train_sets.index.get_level_values(3) == wk][feature_cols]
    drop_cols = X_train.columns[X_train.isna().any()].tolist()
    X_train.drop(drop_cols, axis=1, inplace=True)
    X_train = pd.get_dummies(X_train, columns=['market_name'])
    y_train = df_train_sets[df_train_sets.index.get_level_values(3) == wk][target_cols].to_records(index=False)
    # scores_train[wk] = estimator.score(X_train[estimator.estimator.feature_names_in_], y_train)
    preds_train[wk] = estimator.predict(X_train[estimator.estimator.feature_names_in_])
    # surv_fn_train[wk] = estimator.predict_survival_function(X_train[estimator.estimator.feature_names_in_])

    X_test = df_test_sets[df_test_sets.index.get_level_values(3) == wk][feature_cols]
    X_test = pd.get_dummies(X_test, columns=['market_name'])
    missing_cols = list(set(estimator.estimator.feature_names_in_) - set(X_test.columns))
    print(missing_cols)
    for col in missing_cols:
        X_test[col] = 0
    X_test.drop(drop_cols, axis=1, inplace=True)
    test_idx = X_test[estimator.estimator.feature_names_in_].dropna().index
    y_test = df_test_sets[df_test_sets.index.get_level_values(3) == wk].loc[test_idx, target_cols].to_records(index=False)

    preds_test[wk] = estimator.predict(X_test[estimator.estimator.feature_names_in_].loc[test_idx])
    # surv_fn_test[wk] = estimator.predict_survival_function(X_test[estimator.estimator.feature_names_in_].loc[test_idx])
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['market_name_Minneapolis']
# ['market_name_Minneapolis']
# ['market_name_Minneapolis']
# ['market_name_Minneapolis
#         0.96850197,  0.05023498,  2.58277338,  1.78891716, -2.11162982,
#         3.67591456,  0.35117178, -2.17773678,  0.06562144, -0.4707433 ,
#        -1.46579632, -0.97250765,  0.7804752 ,  1.90685443,  0.32332749,
#        -0.02600093,  3.75511581, -0.77557536,  3.67748268,  0.16469033,
#        -0.82555337,  0.06522618,  0.58768012, -0.37011822, -1.27639784,
#         0.0152891 , -1.55898448, -1.96250172,  2.22555659,  2.28809318,
#        -0.80079783, -1.1624389 , -0.28115571,  2.70379977,  0.55830073,
#         2.99735805, -2.13893187,  3.69977743,  2.27041837, -1.54605217,
#        -0.89389831,  0.07137495, -0.70215935, -0.51294952,  0.75176821,
#         1.48439607,  1.69991341, -1.7928889 ,  0.45361401,  3.05108549,
#         1.51862287,  1.36273557, -1.8459654 ,  1.65028711,  3.59554038,
#        -2.45200899, -0.70131566,  0.36018944,  3.76727865,  2.67974141,
#         1.30092065, -0.02367101,  1.39457206, -1.22079093, -1.32939569,
#        -1.35503896,  1.6650689 , -0.73117582,  0.17997693, -1.43808677,
#        -2.38314596,  3.30486364,  0.22608944, -1.97625459,  4.0462495 ,
#        -0.68408782,  0.37442181,  3.18301197, -1.55293482, -0.14591015,
#        -1.46769456, -1.15016533, -2.25005654,  0.15157354, -2.4735177 ,
#        -2.30709628,  0.70262854,  2.34582695, -0.16911061, -0.82255967,
#        -1.5433147 ,  0.52516161,  0.35304975, -1.53516803, -1.14372576,
#         1.51772615, -1.40999971, -0.75398851, -1.86417989, -0.90259853,
#         0.09536073, -0.88637596, -0.56854671, -0.89635384, -1.23491327,
#        -1.74456917,  0.78416096,  1.30290575,  4.31178775, -1.50336411,
#        -0.9396011 , -2.11088251, -1.84966395, -0.57763083, -1.95798018,
#        -0.73280858, -1.10812267, -1.23894781, -1.59146843, -0.53483483,
#        -1.99552885, -0.59118147, -0.93424864,  1.44342624,  0.82322202,
#        -1.09238993,  1.50170487, -1.03770608, -1.28614802, -1.23758045,
#        -0.41607057, -0.17437034, -1.62618773,  1.04326138, -0.9507487 ,
#        -1.61128382,  0.7162674 ])

# %% [markdown]
# #### predicted survival curves and MAPE for survival time point prediction

# %%
from sksurv.functions import StepFunction
# define function to extract point estimate of survival time from survival curves
def get_percentile_from_step_fn(step_fns_list, percs):
    surv_time_preds=[]
    try:
        for step_fn in step_fns_list:
            idxs = [np.argmin(step_fn.y[step_fn.y >=alpha]) for alpha in percs]
            surv_time_pred = [step_fn.x[idx] for idx in idxs]
            surv_time_preds.append(surv_time_pred)
    except ValueError:
        return
    return surv_time_preds

# %%
def get_prob_from_step_fn(step_fns_list, spins):
    surv_time_preds=[]
    try:
        for step_fn in step_fns_list:
            idxs = [np.argmin(step_fn.x[step_fn.x >=alpha]) for alpha in spins]
            surv_time_pred = [step_fn.y[idx] for idx in idxs]
            surv_time_preds.append(surv_time_pred)
    except ValueError:
        return
    return surv_time_preds

# %%
df_surv_time = pd.DataFrame()
df_surv_time_test = pd.DataFrame()

df_surv_prob_test_all = pd.DataFrame()

for wk in weeks_range:
    start = time.perf_counter()

    estimator = best_estimators_gbm[wk]

    X_train = df_train_sets[df_train_sets.index.get_level_values(3) == wk][feature_cols]
    drop_cols = X_train.columns[X_train.isna().any()].tolist()
    X_train.drop(drop_cols, axis=1, inplace=True)
    X_train = pd.get_dummies(X_train, columns=['market_name'])
    y_train = df_train_sets[df_train_sets.index.get_level_values(3) == wk][target_cols].to_records(index=False)
    surv_fn_train = estimator.predict_survival_function(X_train[estimator.estimator.feature_names_in_])

    alphas = list(np.arange(0,1,0.1)) + [0.25, 0.50, 0.75, 0.95, 0.99]
    alphas = list(np.sort(alphas))
    # alphas = [0.25, 0.50, 0.75]
    surv_time_preds = get_percentile_from_step_fn(surv_fn_train, alphas)
    # df_surv_time_preds = pd.DataFrame(surv_time_preds, columns=['stp_perc_25', 'stp_perc_50', 'stp_perc_75'], index=X_train.index)
    df_surv_time_preds = pd.DataFrame(surv_time_preds, columns=[f'stp_perc_{int(100*i)}' for i in alphas], index=X_train.index)
    df_surv_time_preds = pd.concat([df_surv_time_preds, df_train_sets[df_train_sets.index.get_level_values(3) == wk][target_cols]], axis=1)
    df_surv_time = pd.concat([df_surv_time, df_surv_time_preds])

    X_test = df_test_sets[df_test_sets.index.get_level_values(3) == wk][feature_cols]
    X_test = pd.get_dummies(X_test, columns=['market_name'])
    missing_cols = list(set(estimator.estimator.feature_names_in_) - set(X_test.columns))
    print(missing_cols)
    for col in missing_cols:
        X_test[col] = 0
    test_idx = X_test[estimator.estimator.feature_names_in_].dropna().index
    y_test = df_test_sets[df_test_sets.index.get_level_values(3) == wk].loc[test_idx, target_cols].to_records(index=False)

    surv_fn_test = estimator.predict_survival_function(X_test[estimator.estimator.feature_names_in_].loc[test_idx])

    surv_time_preds_test = get_percentile_from_step_fn(surv_fn_test, alphas)
    # df_surv_time_preds_test = pd.DataFrame(surv_time_preds_test, columns=['stp_perc_25', 'stp_perc_50', 'stp_perc_75'], index=test_idx)
    df_surv_time_preds_test = pd.DataFrame(surv_time_preds_test, columns=[f'stp_perc_{int(100*i)}' for i in alphas], index=test_idx)
    df_surv_time_preds_test = pd.concat([df_surv_time_preds_test, df_test_sets[df_test_sets.index.get_level_values(3) == wk][target_cols]], axis=1)
    df_surv_time_test = pd.concat([df_surv_time_test, df_surv_time_preds_test])


    surv_prob_test = get_prob_from_step_fn(surv_fn_test, [25, 50, 75, 100])
    # df_surv_time_preds_test = pd.DataFrame(surv_time_preds_test, columns=['stp_perc_25', 'stp_perc_50', 'stp_perc_75'], index=test_idx)
    df_surv_prob_test = pd.DataFrame(surv_prob_test, columns=[f'prob_{int(i)}' for i in [25, 50, 75, 100]], index=test_idx)
    df_surv_prob_test = pd.concat([df_surv_prob_test, df_test_sets[df_test_sets.index.get_level_values(3) == wk][target_cols]], axis=1)
    df_surv_prob_test_all = pd.concat([df_surv_prob_test_all, df_surv_prob_test])
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['market_name_Minneapolis']
# ['market_name_Minneapolis']
# ['market_name_Minneapolis']
# ['market_name_Minneapolis']

# %%
df_surv_prob_test_all
# Out:
#                                                        prob_25   prob_50  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2742545      KDHT-FM      2022-04-24 0.0              1.000000  1.000000
# 2780771      KHTS-FM      2022-06-19 0.0              1.000000  1.000000
# 2638380      WDCG-FM      2021-04-18 0.0              1.000000  1.000000
# 2345779      WKSC-FM      2021-02-28 0.0              1.000000  1.000000
# 2553815      WKSC-FM      2021-10-03 0.0              1.000000  1.000000
# ...                                                        ...       ...
# 2552613      WZFT-FM      2020-10-11 26.0             0.995149  0.995149
# 2548688      KKRZ-FM      2020-09-13 26.0             0.994958  0.994958
# 2582475      KHTS-FM      2021-10-17 26.0             0.993022  0.993022
# 2650436      KBKS-FM      2021-07-18 26.0             0.990580  0.990580
# 2723707      KHFI-FM      2022-04-03 26.0             0.993578  0.993578
#
#                                                        prob_75  prob_100  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2742545      KDHT-FM      2022-04-24 0.0              1.000000  1.000000
# 2780771      KHTS-FM      2022-06-19 0.0              1.000000  1.000000
# 2638380      WDCG-FM      2021-04-18 0.0              1.000000  1.000000
# 2345779      WKSC-FM      2021-02-28 0.0              1.000000  1.000000
# 2553815      WKSC-FM      2021-10-03 0.0              1.000000  1.000000
# ...                                                        ...       ...
# 2552613      WZFT-FM      2020-10-11 26.0             0.995149  0.995149
# 2548688      KKRZ-FM      2020-09-13 26.0             0.994958  0.994958
# 2582475      KHTS-FM      2021-10-17 26.0             0.993022  0.993022
# 2650436      KBKS-FM      2021-07-18 26.0             0.990580  0.990580
# 2723707      KHFI-FM      2022-04-03 26.0             0.993578  0.993578
#
#                                                       censoring_flg_mod  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2742545      KDHT-FM      2022-04-24 0.0                          False
# 2780771      KHTS-FM      2022-06-19 0.0                          False
# 2638380      WDCG-FM      2021-04-18 0.0                          False
# 2345779      WKSC-FM      2021-02-28 0.0                          False
# 2553815      WKSC-FM      2021-10-03 0.0                          False
# ...                                                                 ...
# 2552613      WZFT-FM      2020-10-11 26.0                          True
# 2548688      KKRZ-FM      2020-09-13 26.0                          True
# 2582475      KHTS-FM      2021-10-17 26.0                          True
# 2650436      KBKS-FM      2021-07-18 26.0                          True
# 2723707      KHFI-FM      2022-04-03 26.0                          True
#
#                                                       target
# mediabase_id call_letters week_dt    weeks_since_hit
# 2742545      KDHT-FM      2022-04-24 0.0              1515.0
# 2780771      KHTS-FM      2022-06-19 0.0              1491.0
# 2638380      WDCG-FM      2021-04-18 0.0               673.0
# 2345779      WKSC-FM      2021-02-28 0.0               208.0
# 2553815      WKSC-FM      2021-10-03 0.0               101.0
# ...                                                      ...
# 2552613      WZFT-FM      2020-10-11 26.0              176.0
# 2548688      KKRZ-FM      2020-09-13 26.0              492.0
# 2582475      KHTS-FM      2021-10-17 26.0               16.0
# 2650436      KBKS-FM      2021-07-18 26.0              505.0
# 2723707      KHFI-FM      2022-04-03 26.0               50.0
#
# [6658 rows x 6 columns]

# %%
cols = [ col for col in df_surv_time[df_surv_time.index.get_level_values(3) <= 26].columns if 'stp_perc' in col]

# %%
df_train_sets.join(df_surv_time[cols], how='left')
# Out:
#                                                       artist_station_spins_am_pm_dr_13wk_lag2_mean  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2591406      WNCI-FM      2021-09-26 0.0                                                 17.846154
#                           2021-10-03 1.0                                                 19.692308
#                           2021-10-10 2.0                                                 22.076923
#                           2021-10-17 3.0                                                 23.923077
#                           2021-10-24 4.0                                                 24.615385
# ...                                                                                            ...
# 2598403      WXKS-FM      2021-05-09 35.0                                                 0.923077
#                           2021-05-16 36.0                                                 0.846154
#                           2021-05-23 37.0                                                 0.846154
#                           2021-05-30 38.0                                                 0.769231
#                           2021-06-06 39.0                                                 0.692308
#
#                                                       instrumentalness  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2591406      WNCI-FM      2021-09-26 0.0                      0.187540
#                           2021-10-03 1.0                      0.187540
#                           2021-10-10 2.0                      0.187540
#                           2021-10-17 3.0                      0.187540
#                           2021-10-24 4.0                      0.187540
# ...                                                                ...
# 2598403      WXKS-FM      2021-05-09 35.0                     0.045192
#                           2021-05-16 36.0                     0.045192
#                           2021-05-23 37.0                     0.045192
#                           2021-05-30 38.0                     0.045192
#                           2021-06-06 39.0                     0.045192
#
#                                                       artist_station_spins_non_on_4wk_lag2_min  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2591406      WNCI-FM      2021-09-26 0.0                                                
k_lag1_min  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2591406      WNCI-FM      2021-09-26 0.0                                                  27.0
#                           2021-10-03 1.0                                                  27.0
#                           2021-10-10 2.0                                                  27.0
#                           2021-10-17 3.0                                                  27.0
#                           2021-10-24 4.0                                                  27.0
# ...                                                                                        ...
# 2598403      WXKS-FM      2021-05-09 35.0                                                  0.0
#                           2021-05-16 36.0                                                  0.0
#                           2021-05-23 37.0                                                  0.0
#                           2021-05-30 38.0                                                  0.0
#                           2021-06-06 39.0                                                  0.0
#
#                                                       ...  stp_perc_50  \
# mediabase_id call_letters week_dt    weeks_since_hit  ...
# 2591406      WNCI-FM      2021-09-26 0.0              ...        854.0
#                           2021-10-03 1.0              ...        898.0
#                           2021-10-10 2.0              ...        797.0
#                           2021-10-17 3.0              ...        781.0
#                           2021-10-24 4.0              ...          NaN
# ...                                                   ...          ...
# 2598403      WXKS-FM      2021-05-09 35.0             ...          NaN
#                           2021-05-16 36.0             ...          NaN
#                           2021-05-23 37.0             ...          NaN
#                           2021-05-30 38.0             ...          NaN
#                           2021-06-06 39.0             ...          NaN
#
#                                                       stp_perc_50  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2591406      WNCI-FM      2021-09-26 0.0                    854.0
#                           2021-10-03 1.0                    898.0
#                           2021-10-10 2.0                    797.0
#                           2021-10-17 3.0                    781.0
#                           2021-10-24 4.0                      NaN
# ...                                                           ...
# 2598403      WXKS-FM      2021-05-09 35.0                     NaN
#                           2021-05-16 36.0                     NaN
#                           2021-05-23 37.0                     NaN
#                           2021-05-30 38.0                     NaN
#                           2021-06-06 39.0                     NaN
#
#                                                       stp_perc_50  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2591406      WNCI-FM      2021-09-26 0.0                    854.0
#                           2021-10-03 1.0                    898.0
#                           2021-10-10 2.0                    797.0
#                           2021-10-17 3.0                    781.0
#                           2021-10-24 4.0                      NaN
# ...                                                           ...
# 2598403      WXKS-FM      2021-05-09 35.0                     NaN
#                           2021-05-16 36.0                     NaN
#                           2021-05-23 37.0                     NaN
#                           2021-05-30 38.0                     NaN
#                           2021-06-06 39.0                     NaN
#
#                                                       stp_perc_60  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2591406      WNCI-FM      2021-09-26 0.0                    779.0
#                           2021-10-03 1.0                    807.0
#                           2021-10-10 2.0                    694.0
#                           2021-10-17 3.0                    709.0
#                           2021-10-24 4.0                      NaN
# ...                                                           ...
# 2598403      WXKS-FM      2021-05-09 35.0                     NaN
#                           2021-05-16 36.0                     NaN
#                           2021-05-23 37.0                     NaN
#                           2021-05-30 38.0                     NaN
#                           2021-06-06 39.0                     NaN
#
#                                                       stp_perc_70  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2591406      WNCI-FM      2021-09-26 0.0                    666.0
#                           2021-10-03 1.0                    713.0
#                           2021-10-10 2.0                    585.0
#                           2021-10-17 3.0                    624.0
#                           2021-10-24 4.0                      NaN
# ...                                                           ...
# 2598403      WXKS-FM      2021-05-09 35.0                     NaN
#                           2021-05-16 36.0                     NaN
#                           2021-05-23 37.0                     NaN
#                           2021-05-30 38.0                     NaN
#                           2021-06-06 39.0                     NaN
#
#                                                       stp_perc_75  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2591406      WNCI-FM      2021-09-26 0.0                    597.0
#                           2021-10-03 1.0                    650.0
#                           2021-10-10 2.0                    523.0
#                           2021-10-17 3.0                    575.0
#                           2021-10-24 4.0                      NaN
# ...                                                           ...
# 2598403      WXKS-FM      2021-05-09 35.0                     NaN
#                           2021-05-16 36.0                     NaN
#                           2021-05-23 37.0                     NaN
#                           2021-05-30 38.0                     NaN
#                           2021-06-06 39.0                     NaN
#
#                                                       stp_perc_80  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2591406      WNCI-FM      2021-09-26 0.0                    532.0
#                           2021-10-03 1.0                    567.0
#                           2021-10-10 2.0                    427.0
#                           2021-10-17 3.0                    504.0
#                           2021-10-24 4.0                      NaN
# ...                                                           ...
# 2598403      WXKS-FM      2021-05-09 35.0                     NaN
#                           2021-05-16 36.0                     NaN
#                           2021-05-23 37.0                     NaN
#                           2021-05-30 38.0                     NaN
#                           2021-06-06 39.0                     NaN
#
#                                                       stp_perc_90  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2591406      WNCI-FM      2021-09-26 0.0                    381.0
#                           2021-10-03 1.0                    397.0
#                           2021-10-10 2.0                    277.0
#                           2021-10-17 3.0                    343.0
#                           2021-10-24 4.0                      NaN
# ...                                                           ...
# 2598403      WXKS-FM      2021-05-09 35.0                     NaN
#                           2021-05-16 36.0                     NaN
#                           2021-05-23 37.0                     NaN
#                           2021-05-30 38.0                     NaN
#                           2021-06-06 39.0                     NaN
#
#                                                       stp_perc_95  stp_perc_99
# mediabase_id call_letters week_dt    weeks_since_hit
# 2591406      WNCI-FM      2021-09-26 0.0                    275.0        127.0
#                           2021-10-03 1.0                    268.0         88.0
#                           2021-10-10 2.0                    171.0         44.0
#                           2021-10-17 3.0                    235.0         88.0
#                           2021-10-24 4.0                      NaN          NaN
# ...                                                           ...          ...
# 2598403      WXKS-FM      2021-05-09 35.0                     NaN          NaN
#                           2021-05-16 36.0                     NaN          NaN
#                           2021-05-23 37.0                     NaN          NaN
#                           2021-05-30 38.0                     NaN          NaN
#                           2021-06-06 39.0                     NaN          NaN
#
# [36123 rows x 1152 columns]

# %%
df_surv_time = df_surv_time.assign(**{'APE_25': np.abs((df_surv_time['stp_perc_25'] - df_surv_time['target'])/df_surv_time['target']),
                     'APE_50': np.abs((df_surv_time['stp_perc_50'] - df_surv_time['target'])/df_surv_time['target']),
                     'APE_75': np.abs((df_surv_time['stp_perc_75'] - df_surv_time['target'])/df_surv_time['target'])})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_7625/3711207799.py in <cell line: 1>()
#       1 df_surv_time = df_surv_time.assign(**{'APE_25': np.abs((df_surv_time['stp_perc_25'] - df_surv_time['target'])/df_surv_time['target']),
# ----> 2                      'APE_50': np.abs((df_surv_time['stp_perc_50'] - df_surv_time['target'])/df_surv_time['target']),
#       3                      'APE_75': np.abs((df_surv_time['stp_perc_75'] - df_surv_time['target'])/df_surv_time['target'])})
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/core/ops/__init__.py in f(self, other, axis, level, fill_value)
#     649         # TODO: why are we passing flex=True instead of flex=not special?
#     650         #  15 tests fail if we pass flex=not special instead
# --> 651         self, other = _align_method_FRAME(self, other, axis, flex=True, level=level)
#     652
#     653         if isinstance(other, ABCDataFrame):
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/core/ops/__init__.py in _align_method_FRAME(left, right, axis, flex, level)
#     514         # axis=1 is default for DataFrame-with-Series op
#     515         axis = left._get_axis_number(axis) if axis is not None else 1
# --> 516         left, right = left.align(
#     517             right, join="outer", axis=axis, level=level, copy=False
#     518         )
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/core/frame.py in align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#    3960         broadcast_axis=None,
#    3961     ) -> "DataFrame":
# -> 3962         return super().align(
#    3963             other,
#    3964             join=join,
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/core/generic.py in align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#    8563             )
#    8564         elif isinstance(other, ABCSeries):
# -> 8565             return self._align_series(
#    8566                 other,
#    8567                 join=join,
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/core/generic.py in _align_series(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis)
#    8691                 lidx, ridx = None, None
#    8692                 if not self.columns.equals(other.index):
# -> 8693                     join_index, lidx, ridx = self.columns.join(
#    8694                         other.index, how=join, level=level, return_indexers=True
#    8695                     )
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/core/indexes/base.py in join(self, other, how, level, return_indexers, sort)
#    3447                 pass
#    3448             else:
# -> 3449                 return self._join_multi(other, how=how, return_indexers=return_indexers)
#    3450
#    3451         # join on the level
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/core/indexes/base.py in _join_multi(self, other, how, return_indexers)
#    3549         # need at least 1 in common
#    3550         if not overlap:
# -> 3551             raise ValueError("cannot join with no overlapping index names")
#    3552
#    3553         self_is_mi = isinstance(self, ABCMultiIndex)
#
# ValueError: cannot join with no overlapping index names

# %%
df_surv_time[(df_surv_time.index.get_level_values(3) <= 26) & (df_surv_time['censoring_flg_mod'] == True)].apply(lambda x: np.abs((x['stp_perc_75'] - x['target'])/x['target']), axis=1).median()
# Out:
# 0.41397849462365593

# %%
df_surv_time_test[(df_surv_time_test.index.get_level_values(3) <= 26) & (df_surv_time_test['censoring_flg_mod'] == True)].apply(lambda x: np.abs((x['stp_perc_50'] - x['target'])/x['target']), axis=1).mean()
# Out:
# stp_perc_50    3.050902
# stp_perc_50    3.050902
# dtype: float64

# %%
df_surv_time_test = df_surv_time_test.assign(**{'APE_25': np.abs((df_surv_time_test['stp_perc_25'] - df_surv_time_test['target'])/df_surv_time_test['target']),
                     'APE_50': np.abs((df_surv_time_test['stp_perc_50'] - df_surv_time_test['target'])/df_surv_time_test['target']),
                     'APE_75': np.abs((df_surv_time_test['stp_perc_75'] - df_surv_time_test['target'])/df_surv_time_test['target'])})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_7625/1793180586.py in <cell line: 1>()
#       1 df_surv_time_test = df_surv_time_test.assign(**{'APE_25': np.abs((df_surv_time_test['stp_perc_25'] - df_surv_time_test['target'])/df_surv_time_test['target']),
# ----> 2                      'APE_50': np.abs((df_surv_time_test['stp_perc_50'] - df_surv_time_test['target'])/df_surv_time_test['target']),
#       3                      'APE_75': np.abs((df_surv_time_test['stp_perc_75'] - df_surv_time_test['target'])/df_surv_time_test['target'])})
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/core/ops/__init__.py in f(self, other, axis, level, fill_value)
#     649         # TODO: why are we passing flex=True instead of flex=not special?
#     650         #  15 tests fail if we pass flex=not special instead
# --> 651         self, other = _align_method_FRAME(self, other, axis, flex=True, level=level)
#     652
#     653         if isinstance(other, ABCDataFrame):
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/core/ops/__init__.py in _align_method_FRAME(left, right, axis, flex, level)
#     514         # axis=1 is default for DataFrame-with-Series op
#     515         axis = left._get_axis_number(axis) if axis is not None else 1
# --> 516         left, right = left.align(
#     517             right, join="outer", axis=axis, level=level, copy=False
#     518         )
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/core/frame.py in align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#    3960         broadcast_axis=None,
#    3961     ) -> "DataFrame":
# -> 3962         return super().align(
#    3963             other,
#    3964             join=join,
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/core/generic.py in align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#    8563             )
#    8564         elif isinstance(other, ABCSeries):
# -> 8565             return self._align_series(
#    8566                 other,
#    8567                 join=join,
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/core/generic.py in _align_series(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis)
#    8691                 lidx, ridx = None, None
#    8692                 if not self.columns.equals(other.index):
# -> 8693                     join_index, lidx, ridx = self.columns.join(
#    8694                         other.index, how=join, level=level, return_indexers=True
#    8695                     )
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/core/indexes/base.py in join(self, other, how, level, return_indexers, sort)
#    3447                 pass
#    3448             else:
# -> 3449                 return self._join_multi(other, how=how, return_indexers=return_indexers)
#    3450
#    3451         # join on the level
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/core/indexes/base.py in _join_multi(self, other, how, return_indexers)
#    3549         # need at least 1 in common
#    3550         if not overlap:
# -> 3551             raise ValueError("cannot join with no overlapping index names")
#    3552
#    3553         self_is_mi = isinstance(self, ABCMultiIndex)
#
# ValueError: cannot join with no overlapping index names

# %%
df_surv_time.groupby(['censoring_flg_mod']).agg({'APE_25':np.median, 'APE_50':np.median, 'APE_75':np.median})
# Out:
# ---------------------------------------------------------------------------
# SpecificationError                        Traceback (most recent call last)
# /tmp/ipykernel_7625/3226777877.py in <cell line: 1>()
# ----> 1 df_surv_time.groupby(['censoring_flg_mod']).agg({'APE_25':np.median, 'APE_50':np.median, 'APE_75':np.median})
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     949         func = maybe_mangle_lambdas(func)
#     950
# --> 951         result, how = self._aggregate(func, *args, **kwargs)
#     952         if how is None:
#     953             return result
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/core/base.py in _aggregate(self, arg, *args, **kwargs)
#     352                 ) != len(keys):
#     353                     cols = sorted(set(keys) - set(obj.columns.intersection(keys)))
# --> 354                     raise SpecificationError(f"Column(s) {cols} do not exist")
#     355
#     356             from pandas.core.reshape.concat import concat
#
# SpecificationError: Column(s) ['APE_25', 'APE_50', 'APE_75'] do not exist

# %%
df_surv_time_test[df_surv_time_test['target'] <= 100].groupby(['weeks_since_hit', 'censoring_flg_mod']).agg({'APE_25':np.median, 'APE_50':np.median, 'APE_75':np.median})
# Out:
#                                        APE_25     APE_50     APE_75
# weeks_since_hit censoring_flg_mod
# 0.0             False                9.996872   6.839625   4.431083
#                 True                 6.673771   4.462366   2.666283
# 1.0             False               10.200000   8.000000   5.294737
#                 True                 7.515110   4.857143   2.293956
# 2.0             False               14.331170  10.720970   6.323115
#                 True                10.666180   6.849003   3.484330
# 3.0             False               13.119048   9.404762   5.357143
#                 True                 9.710526   7.015789   3.744168
# 4.0             False               13.128205   8.948718   4.666667
#                 True                 5.238095   3.119048   1.428571
# ...                                                                                        ...
# 2584541      WDCG-FM      2021-06-13 1.0                                              0.994737
#                           2021-06-20 2.0                                              0.994737
#                           2021-06-27 3.0                                              0.994737
#                           2021-07-04 4.0                                              0.994737
#                           2021-07-11 5.0                                              0.994737
#
#                                                       censoring_flg_mod  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2742545      KDHT-FM      2022-04-24 0.0                          False
#                           2022-05-01 1.0                          False
#                           2022-05-08 2.0                          False
#                           2022-05-15 3.0                          False
#                           2022-05-22 4.0                          False
# ...                                                                 ...
# 2584541      WDCG-FM      2021-06-13 1.0                           True
#                           2021-06-20 2.0                           True
#                           2021-06-27 3.0                           True
#                           2021-07-04 4.0                           True
#                           2021-07-11 5.0                           True
#
#                                                       target      pred  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2742545      KDHT-FM      2022-04-24 0.0              1515.0  0.573759
#                           2022-05-01 1.0              1418.0  1.408200
#                           2022-05-08 2.0              1320.0  0.507064
#                           2022-05-15 3.0              1253.0  0.244193
#                           2022-05-22 4.0              1178.0 -1.068064
# ...                                                      ...       ...
# 2584541      WDCG-FM      2021-06-13 1.0               475.0  0.676340
#                           2021-06-20 2.0               378.0  0.785689
#                           2021-06-27 3.0               283.0  2.151535
#                           2021-07-04 4.0               188.0  2.124255
#                           2021-07-11 5.0                93.0  1.134395
#
#                                                       pred_quintile  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2742545      KDHT-FM      2022-04-24 0.0                        3.0
#                           2022-05-01 1.0                        4.0
#                           2022-05-08 2.0                        3.0
#                           2022-05-15 3.0                        2.0
#                           2022-05-22 4.0                        1.0
# ...                                                             ...
# 2584541      WDCG-FM      2021-06-13 1.0                        3.0
#                           2021-06-20 2.0                        3.0
#                           2021-06-27 3.0                        4.0
#                           2021-07-04 4.0                        4.0
#                           2021-07-11 5.0                        3.0
#
#                                                       pred_quintile_all
# mediabase_id call_letters week_dt    weeks_since_hit
# 2742545      KDHT-FM      2022-04-24 0.0                            3.0
#                           2022-05-01 1.0                            4.0
#                           2022-05-08 2.0                            3.0
#                           2022-05-15 3.0                            2.0
#                           2022-05-22 4.0                            1.0
# ...                                                                 ...
# 2584541      WDCG-FM      2021-06-13 1.0                            3.0
#                           2021-06-20 2.0                            3.0
#                           2021-06-27 3.0                            4.0
#                           2021-07-04 4.0                            4.0
#                           2021-07-11 5.0                            3.0
#
# [12117 rows x 1137 columns]

# %% [markdown]
# #### Examine Confusion Matrix

# %%
df_train_sets['pred'] = np.nan
df_test_sets['pred'] = np.nan

# %%
df_train_sets.columns
# Out:
# Index(['artist_station_spins_am_pm_dr_13wk_lag2_mean', 'instrumentalness',
#        'artist_station_spins_non_on_4wk_lag2_min',
#        'artist_format_ddl_4wk_lag1_mean', 'thumbs_down_count_26wk_lag2_max',
#        'station_spins_ddl_sens_26wk_lag1_min',
#        'artist_format_spins_am_pm_dr_26wk_lag2_mean',
#        'stream_count_26wk_lag2_max',
#        'artist_station_spins_non_on_13wk_lag2_min',
#        'artist_market_spins_non_on_13wk_lag1_min',
#        ...
#        'artist_format_spins_am_pm_dr_26wk_lag2_min',
#        'song_station_ddl_26wk_lag1_min', 'ddl_quintile_2-4_apps_lag1',
#        'completed_count_1wk_lag1_mean',
#        'song_market_spins_non_on_13wk_lag2_mean',
#        'song_station_spins_non_on_delta_4wk_lag2_max',
#        'station_spins_ddl_sens_abs_13wk_lag2_max', 'censoring_flg_mod',
#        'target', 'pred'],
#       dtype='object', length=1135)

# %%
for wk in weeks_range:
    # print(df_train_sets[df_train_sets.index.get_level_values(3) == wk].shape)
    df_train_sets.loc[df_train_sets.index.get_level_values(3) == wk, 'pred'] = preds_train[wk]
    df_test_sets.loc[df_test_sets.index.get_level_values(3) == wk, 'pred'] = preds_test[wk]
    # print(len(preds_train[wk]))

# %%
df_sub = df_test_sets[(df_test_sets.index.get_level_values(3) == 15) & (df_test_sets['censoring_flg_mod'] == False)].sort_values(by=['target'])

# %%
import matplotlib.pyplot as plt
plt.scatter(df_sub['target'], df_sub['pred'])

# %%
df_train_sets['pred_quintile'] = df_train_sets.groupby(['weeks_since_hit', 'censoring_flg_mod']).apply(lambda x: pd.qcut(x['pred'], q=5, labels=False)).droplevel([0,1])
df_test_sets['pred_quintile'] = df_test_sets.groupby(['weeks_since_hit', 'censoring_flg_mod']).apply(lambda x: pd.qcut(x['pred'], q=5, labels=False)).droplevel([0,1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_7625/470637230.py in <cell line: 1>()
# ----> 1 df_train_sets['pred_quintile'] = df_train_sets.groupby(['weeks_since_hit', 'censoring_flg_mod']).apply(lambda x: pd.qcut(x['pred'], q=5, labels=False)).droplevel([0,1])
#       2 df_test_sets['pred_quintile'] = df_test_sets.groupby(['weeks_since_hit', 'censoring_flg_mod']).apply(lambda x: pd.qcut(x['pred'], q=5, labels=False)).droplevel([0,1])
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     857         with option_context("mode.chained_assignment", None):
#     858             try:
# --> 859                 result = self._python_apply_general(f, self._selected_obj)
#     860             except TypeError:
#     861                 # gh-20949
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data)
#     890             data after applying f
#     891         """
# --> 892         keys, values, mutated = self.grouper.apply(f, data, self.axis)
#     893
#     894         return self._wrap_applied_output(
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     218             # group might be modified
#     219             group_axes = group.axes
# --> 220             res = f(group)
#     221             if not _is_indexed_like(res, group_axes):
#     222                 mutated = True
#
# /tmp/ipykernel_7625/470637230.py in <lambda>(x)
# ----> 1 df_train_sets['pred_quintile'] = df_train_sets.groupby(['weeks_since_hit', 'censoring_flg_mod']).apply(lambda x: pd.qcut(x['pred'], q=5, labels=False)).droplevel([0,1])
#       2 df_test_sets['pred_quintile'] = df_test_sets.groupby(['weeks_since_hit', 'censoring_flg_mod']).apply(lambda x: pd.qcut(x['pred'], q=5, labels=False)).droplevel([0,1])
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/core/reshape/tile.py in qcut(x, q, labels, retbins, precision, duplicates)
#     358         quantiles = q
#     359     bins = algos.quantile(x, quantiles)
# --> 360     fac, bins = _bins_to_cuts(
#     361         x,
#     362         bins,
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/core/reshape/tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates, ordered)
#     399     if len(unique_bins) < len(bins) and len(bins) != 2:
#     400         if duplicates == "raise":
# --> 401             raise ValueError(
#     402                 f"Bin edges must be unique: {repr(bins)}.\n"
#     403                 f"You can drop duplicate edges by setting the 'duplicates' kwarg"
#
# ValueError: Bin edges must be unique: array([nan, nan, nan, nan, nan, nan]).
# You can drop duplicate edges by setting the 'duplicates' kwarg

# %%
df_train_sets['target_quintile'] = df_train_sets.groupby(['weeks_since_hit', 'censoring_flg_mod']).apply(lambda x: pd.qcut(x['target'], q=5, labels=[4,3,2,1,0])).droplevel([0,1])

# %%
from sklearn.metrics import  ConfusionMatrixDisplay, confusion_matrix
preds = df_train_sets.loc[(df_train_sets.index.get_level_values(3)==4) & (df_train_sets['censoring_flg_mod'] == True)]['pred_quintile']
true = df_train_sets.loc[(df_train_sets.index.get_level_values(3)==4) & (df_train_sets['censoring_flg_mod'] == True)]['target_quintile']
cm= confusion_matrix(true, preds, labels=[0,1,2,3,4])
cf = ConfusionMatrixDisplay(cm)
cf.from_predictions(true, preds)

# %%
cm
# Out:
# array([[92, 35,  7,  1,  0],
#        [32, 57, 31, 14,  0],
#        [10, 32, 51, 37,  4],
#        [ 1,  9, 33, 51, 40],
#        [ 0,  1, 12, 31, 91]])

# %% [markdown]
# #### Explore time-dependent AUC

# %%
from sksurv.metrics import cumulative_dynamic_auc
times = np.arange(25,1005, 5)
times_2 = np.arange(25,505, 5)
mean_auc_wk = {}
for wk in weeks_range:
    start = time.perf_counter()

    estimator = best_estimators_gbm[wk]

    X_train = df_train_sets[df_train_sets.index.get_level_values(3) == wk][feature_cols]
    drop_cols = X_train.columns[X_train.isna().any()].tolist()
    X_train.drop(drop_cols, axis=1, inplace=True)
    X_train = pd.get_dummies(X_train, columns=['market_name'])
    y_train = df_train_sets[df_train_sets.index.get_level_values(3) == wk][target_cols].to_records(index=False)


    X_test = df_test_sets[df_test_sets.index.get_level_values(3) == wk][feature_cols]
    X_test = pd.get_dummies(X_test, columns=['market_name'])
    missing_cols = list(set(estimator.estimator.feature_names_in_) - set(X_test.columns))
    print(missing_cols)
    for col in missing_cols:
        X_test[col] = 0

    test_idx = X_test[estimator.estimator.feature_names_in_].dropna().index
    y_test = df_test_sets[df_test_sets.index.get_level_values(3) == wk].loc[test_idx, target_cols].to_records(index=False)

    risk_scores = estimator.predict(X_test.loc[test_idx, estimator.estimator.feature_names_in_])
    if wk <= 15:
        roc_auc, mean_auc=cumulative_dynamic_auc(y_train, y_test, risk_scores, times)
        if wk == 10:
            plt.plot(times, roc_auc, marker='o')
            plt.axhline(mean_auc, linestyle='--')
            plt.title('AUC by spins level for week 10 from hit')
            plt.xlabel('Incremental Spins from Week 10')
            plt.ylabel('AUC')
            plt.savefig('AUC_week_10.jpeg', format='jpeg')
    else:
        roc_auc, mean_auc=cumulative_dynamic_auc(y_train, y_test, risk_scores, times_2)
        # plt.plot(times_2, roc_auc, marker='o')
        # plt.axhline(mean_auc, linestyle='--')
        # plt.show()

    mean_auc_wk[wk] = mean_auc
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['market_name_Minneapolis']
# ['market_name_Minneapolis']
# ['market_name_Minneapolis']
# ['market_name_Minneapolis']

# %%
plt.plot(mean_auc_wk.keys(), [mean_auc_wk[i] for i in mean_auc_wk.keys()], marker = 'o')
plt.axhline(y=0.8, linestyle='--')
plt.title('Model Performance for EBW model')
plt.xlabel('weeks since turning hit')
plt.ylabel('Area under ROC Curve')
# plt.savefig('ebw_auc_h1.jpeg', format='jpeg', dpi=300)
# Out:
# Text(0, 0.5, 'Area under ROC Curve')

# %%
df_rep = df_train_sets.groupby(['weeks_since_hit', 'censoring_flg_mod'])[['target']].count().join(df_test_sets.groupby(['weeks_since_hit', 'censoring_flg_mod'])['target'].count(), rsuffix='_r')
df_rep.columns=['train_samples', 'test_samples']

# %%
df_rep_pvt = df_rep.reset_index().pivot_table(index=['weeks_since_hit'], columns=['censoring_flg_mod'], values=['train_samples', 'test_samples'])

# %%
df_rep_pvt.columns = ['test_samples_False', 'test_samples_True', 'train_samples_False', 'train_samples_True']

# %%
df_rep_pvt.reset_index().to_excel('samples_ebw.xlsx')

# %%
df_rep_pvt = df_rep_pvt[df_rep_pvt.index.get_level_values(0) <= 26]

# %%
df_rep_pvt
# Out:
#                   test_samples        train_samples
# censoring_flg_mod        False  True          False  True
# weeks_since_hit
# 0.0                      103.0  239.0         305.0  717.0
# 1.0                      103.0  239.0         305.0  717.0
# 2.0                      103.0  234.0         305.0  706.0
# 3.0                      103.0  234.0         305.0  699.0
# 4.0                      103.0  225.0         305.0  671.0
# 5.0                      103.0  222.0         304.0  655.0
# 6.0                      103.0  207.0         304.0  624.0
# 7.0                      103.0  202.0         302.0  598.0
# 8.0                      103.0  193.0         302.0  563.0
# 9.0                      103.0  188.0         300.0  543.0
# 10.0                     103.0  173.0         300.0  495.0
# 11.0                     103.0  164.0         300.0  470.0
# 12.0                     103.0  151.0         300.0  436.0
# 13.0                     102.0  141.0         300.0  405.0
# 14.0                     102.0  134.0         300.0  371.0
# 15.0                     102.0  123.0         300.0  353.0
# 16.0                     102.0  113.0         299.0  325.0
# 17.0                     102.0  107.0         299.0  298.0
# 18.0                     102.0   97.0         299.0  277.0
# 19.0                     102.0   87.0         299.0  256.0
# 20.0                     102.0   76.0         298.0  243.0
# 21.0                     102.0   74.0         298.0  224.0
# 22.0                     102.0   66.0         297.0  203.0
# 23.0                     100.0   61.0         296.0  193.0
# 24.0                      99.0   55.0         295.0  173.0
# 25.0                      98.0   52.0         294.0  164.0
# 26.0                      98.0   47.0         293.0  147.0

# %%
df_rep_pvt.reset_index(inplace=True)

# %%
df_rep_pvt['weeks_since_hit'] = df_rep_pvt['weeks_since_hit'].astype(int)

# %%
df_rep_pvt[['train_samples_False', 'train_samples_True']]
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### Burn rate chart

# %%
df_train_sets
# Out:
#                                                       artist_station_spins_am_pm_dr_13wk_lag2_mean  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2591406      WNCI-FM      2021-09-26 0.0                                                 17.846154
#                           2021-10-03 1.0                                                 19.692308
#                           2021-10-10 2.0                                                 22.076923
#                           2021-10-17 3.0                                                 23.923077
#                           2021-10-24 4.0                                                 24.615385
# ...                                                                                            ...
# 2598403      WXKS-FM      2021-02-07 22.0                                                21.307692
#                           2021-02-14 23.0                                                17.538462
#                           2021-02-21 24.0                                                13.769231
#                           2021-02-28 25.0                                                10.230769
#                           2021-03-07 26.0                                                 6.384615
#
#                                                       instrumentalness  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2591406      WNCI-FM      2021-09-26 0.0                      0.187540
#                           2021-10-03 1.0                      0.187540
#                           2021-10-10 2.0                      0.187540
#                           2021-10-17 3.0                      0.187540
#                           2021-10-24 4.0                      0.187540
# ...                                                                ...
# 2598403      WXKS-FM      2021-02-07 22.0                     0.045192
#                           2021-02-14 23.0                     0.045192
#                           2021-02-21 24.0                     0.045192
#                           2021-02-28 25.0                     0.045192
#                           2021-03-07 26.0                     0.045192
#
#                                                       artist_station_spins_non_on_4wk_lag2_min  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2591406      WNCI-FM      2021-09-26 0.0                                                  16.0
#                           2021-10-03 1.0                                                  21.0
#                           2021-10-10 2.0                                                  21.0
#                           2021-10-17 3.0                                                  21.0
#                           2021-10-24 4.0                                                  34.0
# ...                                                                                        ...
# 2598403      WXKS-FM      2021-02-07 22.0                                                  0.0
#                           2021-02-14 23.0                                                  0.0
#                           2021-02-21 24.0                                                  0.0
#                           2021-02-28 25.0                                                  0.0
#                           2021-03-07 26.0                                                  0.0
#
#                                                       artist_format_ddl_4wk_lag1_mean  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2591406      WNCI-FM      2021-09-26 0.0                                    12.500000
#                           2021-10-03 1.0                                    12.000000
#                           2021-10-10 2.0                                    11.750000
#                           2021-10-17 3.0                                    11.750000
#                           2021-10-24 4.0                                    12.000000
# ...                                                                               ...
# 2598403      WXKS-FM      2021-02-07 22.0                                   12.500000
#                           2021-02-14 23.0                                   15.333333
#                           2021-02-21 24.0                                   14.666667
#                           2021-02-28 25.0                                   14.000000
#                           2021-03-07 26.0                                   14.500000
#
#                                                       thumbs_down_count_26wk_lag2_max  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2591406      WNCI-FM      2021-09-26 0.0                                          0.0
#                           2021-10-03 1.0                                          0.0
#                           2021-10-10 2.0                                          0.0
#                           2021-10-17 3.0                                          0.0
#                           2021-10-24 4.0                                          0.0
# ...                                                                               ...
# 2598403      WXKS-FM      2021-02-07 22.0                                         0.0
#                           2021-02-14 23.0                                         0.0
#                           2021-02-21 24.0                                         0.0
#                           2021-02-28 25.0                                         0.0
#                           2021-03-07 26.0                                         0.0
#
#                                                       station_spins_ddl_sens_26wk_lag1_min  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2591406      WNCI-FM      2021-09-26 0.0                
#                           2021-10-24 4.0               381.0 -0.049315
# ...                                                      ...       ...
# 2598403      WXKS-FM      2021-02-07 22.0               17.0  5.156594
#                           2021-02-14 23.0               16.0  0.052339
#                           2021-02-21 24.0               15.0  0.005406
#                           2021-02-28 25.0               15.0  0.953855
#                           2021-03-07 26.0               15.0  0.427875
#
# [19630 rows x 1135 columns]

# %%
df_test_sets[(df_test_sets.index.get_level_values(3) <= 26) & (~pd.isna(df_test_sets['pred']))]
# Out:
#                                                       artist_station_spins_am_pm_dr_13wk_lag2_mean  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2742545      KDHT-FM      2022-04-24 0.0                                                 81.500000
#                           2022-05-01 1.0                                                 81.400000
#                           2022-05-08 2.0                                                 80.500000
#                           2022-05-15 3.0                                                 81.285714
#                           2022-05-22 4.0                                                 82.500000
# ...                                                                                            ...
# 2584541      WDCG-FM      2021-06-13 1.0                                                 56.846154
#                           2021-06-20 2.0                                                 56.923077
#                           2021-06-27 3.0                                                 57.923077
#                           2021-07-04 4.0                                                 61.923077
#                           2021-07-11 5.0                                                 65.230769
#
#                                                       instrumentalness  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2742545      KDHT-FM      2022-04-24 0.0                      0.111254
#                           2022-05-01 1.0                      0.111254
#                           2022-05-08 2.0                      0.111254
#                           2022-05-15 3.0                      0.111254
#                           2022-05-22 4.0                      0.111254
# ...                                                                ...
# 2584541      WDCG-FM      2021-06-13 1.0                      0.046758
#                           2021-06-20 2.0                      0.046758
#                           2021-06-27 3.0                      0.046758
#                           2021-07-04 4.0                      0.046758
#                           2021-07-11 5.0                      0.046758
#
#                                                       artist_station_spins_non_on_4wk_lag2_min  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2742545      KDHT-FM      2022-04-24 0.0                                                  76.0
#                           2022-05-01 1.0                                                 111.0
#                           2022-05-08 2.0                                                 101.0
#                           2022-05-15 3.0                                                 101.0
#                           2022-05-22 4.0                                                 101.0
# ...                                                                                        ...
# 2584541      WDCG-FM      2021-06-13 1.0                                                  96.0
#                           2021-06-20 2.0                                                  80.0
#                           2021-06-27 3.0                                                  80.0
#                           2021-07-04 4.0                                                  80.0
#                           2021-07-11 5.0                                                  80.0
#
#                                                       artist_format_ddl_4wk_lag1_mean  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2742545      KDHT-FM      2022-04-24 0.0                                    16.000000
#                           2022-05-01 1.0                                    16.250000
#                           2022-05-08 2.0                                    16.500000
#                           2022-05-15 3.0                                    16.750000
#                           2022-05-22 4.0                                    17.000000
# ...                                                                               ...
# 2584541      WDCG-FM      2021-06-13 1.0                                    15.000000
#                           2021-06-20 2.0                                    15.250000
#                           2021-06-27 3.0                                    16.000000
#                           2021-07-04 4.0                                    16.333333
#                           2021-07-11 5.0                                    17.333333
#
#                                                       thumbs_down_count_26wk_lag2_max  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2742545      KDHT-FM      2022-04-24 0.0                                          0.0
#                           2022-05-01 1.0                                          0.0
#                           2022-05-08 2.0                                          0.0
#                           2022-05-15 3.0                                          0.0
#                           2022-05-22 4.0                                          0.0
# ...                                                                               ...
# 2584541      WDCG-FM      2021-06-13 1.0                                          0.0
#                           2021-06-20 2.0                                          0.0
#                           2021-06-27 3.0                                          0.0
#                           2021-07-04 4.0                                          0.0
#                           2021-07-11 5.0                                          0.0
#
#                                                       station_spins_ddl_sens_26wk_lag1_min  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2742545      KDHT-FM      2022-04-24 0.0                                          -20.0000
#                           2022-05-01 1.0                                          -20.0000
#                           2022-05-08 2.0                                          -20.0000
#                           2022-05-15 3.0                                          -20.0000
#                           2022-05-22 4.0                                          -20.0000
# ...                                                                                    ...
# 2584541      WDCG-FM      2021-06-13 1.0                                           -0.3663
#                           2021-06-20 2.0                                           -0.3663
#                           2021-06-27 3.0                                           -0.3663
#                           2021-07-04 4.0                                           -0.3663
#                           2021-07-11 5.0                                           -0.3663
#
#                                                       artist_format_spins_am_pm_dr_26wk_lag2_mean  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2742545      KDHT-FM      2022-04-24 0.0                                
0
# ...                                                                          ...
# 2584541      WDCG-FM      2021-06-13 1.0                                     1.0
#                           2021-06-20 2.0                                     1.0
#                           2021-06-27 3.0                                     2.0
#                           2021-07-04 4.0                                     2.0
#                           2021-07-11 5.0                                     2.0
#
#                                                       completed_count_1wk_lag1_mean  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2742545      KDHT-FM      2022-04-24 0.0                                        6.0
#                           2022-05-01 1.0                                        6.0
#                           2022-05-08 2.0                                        6.0
#                           2022-05-15 3.0                                        6.0
#                           2022-05-22 4.0                                        6.0
# ...                                                                             ...
# 2584541      WDCG-FM      2021-06-13 1.0                                        6.0
#                           2021-06-20 2.0                                        6.0
#                           2021-06-27 3.0                                        6.0
#                           2021-07-04 4.0                                        6.0
#                           2021-07-11 5.0                                        6.0
#
#                                                       song_market_spins_non_on_13wk_lag2_mean  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2742545      KDHT-FM      2022-04-24 0.0                                           154.750000
#                           2022-05-01 1.0                                           159.000000
#                           2022-05-08 2.0                                           158.000000
#                           2022-05-15 3.0                                           157.428571
#                           2022-05-22 4.0                                           157.000000
# ...                                                                                       ...
# 2584541      WDCG-FM      2021-06-13 1.0                                            61.307692
#                           2021-06-20 2.0                                            64.769231
#                           2021-06-27 3.0                                            69.846154
#                           2021-07-04 4.0                                            78.846154
#                           2021-07-11 5.0                                            87.538462
#
#                                                       song_station_spins_non_on_delta_4wk_lag2_max  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2742545      KDHT-FM      2022-04-24 0.0                                                      37.0
#                           2022-05-01 1.0                                                      37.0
#                           2022-05-08 2.0                                                       2.0
#                           2022-05-15 3.0                                                       1.0
#                           2022-05-22 4.0                                                       1.0
# ...                                                                                            ...
# 2584541      WDCG-FM      2021-06-13 1.0                                                      29.0
#                           2021-06-20 2.0                                                      19.0
#                           2021-06-27 3.0                                                      21.0
#                           2021-07-04 4.0                                                      34.0
#                           2021-07-11 5.0                                                      34.0
#
#                                                       station_spins_ddl_sens_abs_13wk_lag2_max  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2742545      KDHT-FM      2022-04-24 0.0                                             20.000000
#                           2022-05-01 1.0                                             20.000000
#                           2022-05-08 2.0                                             20.000000
#                           2022-05-15 3.0                                             20.000000
#                           2022-05-22 4.0                                             20.000000
# ...                                                                                        ...
# 2584541      WDCG-FM      2021-06-13 1.0                                              0.994737
#                           2021-06-20 2.0                                              0.994737
#                           2021-06-27 3.0                                              0.994737
#                           2021-07-04 4.0                                              0.994737
#                           2021-07-11 5.0                                              0.994737
#
#                                                       censoring_flg_mod  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2742545      KDHT-FM      2022-04-24 0.0                          False
#                           2022-05-01 1.0                          False
#                           2022-05-08 2.0                          False
#                           2022-05-15 3.0                          False
#                           2022-05-22 4.0                          False
# ...                                                                 ...
# 2584541      WDCG-FM      2021-06-13 1.0                           True
#                           2021-06-20 2.0                           True
#                           2021-06-27 3.0                           True
#                           2021-07-04 4.0                           True
#                           2021-07-11 5.0                           True
#
#                                                       target      pred
# mediabase_id call_letters week_dt    weeks_since_hit
# 2742545      KDHT-FM      2022-04-24 0.0              1515.0  0.573759
#                           2022-05-01 1.0              1418.0  1.408200
#                           2022-05-08 2.0              1320.0  0.507064
#                           2022-05-15 3.0              1253.0  0.244193
#                           2022-05-22 4.0              1178.0 -1.068064
# ...                                                      ...       ...
# 2584541      WDCG-FM      2021-06-13 1.0               475.0  0.676340
#                           2021-06-20 2.0               378.0  0.785689
#                           2021-06-27 3.0               283.0  2.151535
#                           2021-07-04 4.0               188.0  2.124255
#                           2021-07-11 5.0                93.0  1.134395
#
# [6658 rows x 1135 columns]

# %%
mask_missing_preds = ~pd.isna(df_test_sets['pred'])
df_test_sets.loc[mask_missing_preds]
# Out:
#                                                       artist_station_spins_am_pm_dr_13wk_lag2_mean  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2742545      KDHT-FM      2022-04-24 0.0                                                 81.500000
#                           2022-05-01 1.0                                                 81.400000
#                           2022-05-08 2.0                                                 80.500000
#                           2022-05-15 3.0                                                 81.285714
#                           2022-05-22 4.0                                                 82.500000
# ...                                                                                            ...
# 2584541      WDCG-FM      2021-06-13 1.0                                                
\
# mediabase_id call_letters week_dt    weeks_since_hit
# 2742545      KDHT-FM      2022-04-24 0.0                                           154.750000
#                           2022-05-01 1.0                                           159.000000
#                           2022-05-08 2.0                                           158.000000
#                           2022-05-15 3.0                                           157.428571
#                           2022-05-22 4.0                                           157.000000
# ...                                                                                       ...
# 2584541      WDCG-FM      2021-06-13 1.0                                            61.307692
#                           2021-06-20 2.0                                            64.769231
#                           2021-06-27 3.0                                            69.846154
#                           2021-07-04 4.0                                            78.846154
#                           2021-07-11 5.0                                            87.538462
#
#                                                       song_station_spins_non_on_delta_4wk_lag2_max  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2742545      KDHT-FM      2022-04-24 0.0                                                      37.0
#                           2022-05-01 1.0                                                      37.0
#                           2022-05-08 2.0                                                       2.0
#                           2022-05-15 3.0                                                       1.0
#                           2022-05-22 4.0                                                       1.0
# ...                                                                                            ...
# 2584541      WDCG-FM      2021-06-13 1.0                                                      29.0
#                           2021-06-20 2.0                                                      19.0
#                           2021-06-27 3.0                                                      21.0
#                           2021-07-04 4.0                                                      34.0
#                           2021-07-11 5.0                                                      34.0
#
#                                                       station_spins_ddl_sens_abs_13wk_lag2_max  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2742545      KDHT-FM      2022-04-24 0.0                                             20.000000
#                           2022-05-01 1.0                                             20.000000
#                           2022-05-08 2.0                                             20.000000
#                           2022-05-15 3.0                                             20.000000
#                           2022-05-22 4.0                                             20.000000
# ...                                                                                        ...
# 2584541      WDCG-FM      2021-06-13 1.0                                              0.994737
#                           2021-06-20 2.0                                              0.994737
#                           2021-06-27 3.0                                              0.994737
#                           2021-07-04 4.0                                              0.994737
#                           2021-07-11 5.0                                              0.994737
#
#                                                       censoring_flg_mod  \
# mediabase_id call_letters week_dt    weeks_since_hit
# 2742545      KDHT-FM      2022-04-24 0.0                          False
#                           2022-05-01 1.0                          False
#                           2022-05-08 2.0                          False
#                           2022-05-15 3.0                          False
#                           2022-05-22 4.0                          False
# ...                                                                 ...
# 2584541      WDCG-FM      2021-06-13 1.0                           True
#                           2021-06-20 2.0                           True
#                           2021-06-27 3.0                           True
#                           2021-07-04 4.0                           True
#                           2021-07-11 5.0                           True
#
#                                                       target      pred
# mediabase_id call_letters week_dt    weeks_since_hit
# 2742545      KDHT-FM      2022-04-24 0.0              1515.0  0.573759
#                           2022-05-01 1.0              1418.0  1.408200
#                           2022-05-08 2.0              1320.0  0.507064
#                           2022-05-15 3.0              1253.0  0.244193
#                           2022-05-22 4.0              1178.0 -1.068064
# ...                                                      ...       ...
# 2584541      WDCG-FM      2021-06-13 1.0               475.0  0.676340
#                           2021-06-20 2.0               378.0  0.785689
#                           2021-06-27 3.0               283.0  2.151535
#                           2021-07-04 4.0               188.0  2.124255
#                           2021-07-11 5.0                93.0  1.134395
#
# [6658 rows x 1135 columns]

# %%
df_train_sets.loc[:, 'pred_quintile'] = df_train_sets.groupby(['weeks_since_hit', 'censoring_flg_mod']).apply(lambda x: pd.qcut(x['pred'], q=5, labels=False)).droplevel([0,1])

# %%
df_train_sets.loc[:, 'pred_quintile_all'] = df_train_sets.groupby(['weeks_since_hit']).apply(
    lambda x: pd.qcut(x['pred'], q=5, labels=False)).droplevel([0])

# %%
df_test_sets.loc[:, 'pred_quintile'] = df_test_sets.groupby(['weeks_since_hit', 'censoring_flg_mod']).apply(lambda x: pd.qcut(x['pred'], q=5, labels=False)).droplevel([0,1])

# %%
df_test_sets.loc[:, 'pred_quintile_all'] = df_test_sets.groupby(['weeks_since_hit']).apply(lambda x: pd.qcut(x['pred'], q=5, labels=False)).droplevel([0])

# %%
from sqlalchemy import create_engine


def postgresql_engine(user, pwd, host, port, dbname):
    # Need psycopg2-binary package
    sql_engine = create_engine('postgres://' + user + ':' + pwd + '@' + host + ':' + port + '/' + dbname, echo=False)
    return sql_engine


# DB username & password
import getpass

username = getpass.getpass()
password = getpass.getpass()


# misc db parameters
url = 'adds-postgres-dev.cfgztrijqgvp.us-east-1.rds.amazonaws.com'
database = 'musiclab'
port = '5432'

#create db engine
engine = postgresql_engine(username, password, url, port, database)

# %%
sql_cols = ['pred', 'target','censoring_flg_mod', 'pred_quintile', 'pred_quintile_all']
with engine.connect() as conn:
    with conn.begin():
        df_train_sets[sql_cols].to_sql('ebw_train_set_h1', con=conn, schema='adds_temp', method='multi')
        df_test_sets[sql_cols].to_sql('ebw_test_set_h1', con=conn, schema='adds_temp', method='multi')

# %%
df_sub = df_test_sets

# %%
df_sub.groupby(['weeks_since_hit', 'pred_quintile_all', 'censoring_flg_mod'])[['target']].count().join(df_sub.groupby(['weeks_since_hit', 'pred_quintile_all', 'censoring_flg_mod'])['target'].mean(), rsuffix='_r').reset_index().to_excel('test_target_h1.xlsx')

# %%
df_sub.groupby(['weeks_since_hit', 'pred_quintile_all'])[['target']].count().join(df_sub.groupby(['weeks_since_hit', 'pred_quintile_all'])['target'].mean(), rsuffix='_r')
# Out:
#                                    target     target_r
# weeks_since_hit pred_quintile_all
# 0.0             0.0                    69  1594.043478
#                 1.0                    68  1323.955882
#                 2.0                    68   896.558824
#                 3.0                    68   589.014706
#                 4.0                    69   309.637681
# ...                                   ...          ...
# 26.0            0.0                    29   598.034483
#                 1.0                    29   176.275862
#                 2.0                    29   169.827586
#                 3.0                    29   125.379310
#                 4.0                    29   317.448276
#
# [135 rows x 2 columns]

# %%
df_sub.groupby(['weeks_since_hit', 'pred_quintile'])[['burn_before_100_flg']].count().join(df_sub.groupby(['weeks_since_hit', 'pred_quintile'])['burn_before_100_flg'].sum(), rsuffix='_r')

# %% [markdown]
# #### Spins to burn min analysis

# %%
df_expt = df_train_sets.join(df_surv_time[cols], how='inner')
idx = df_expt[cols].dropna().index
df_expt = df_expt.loc[idx]

# %%
df_expt.groupby(['weeks_since_hit'])['target'].count()
# Out:
# weeks_since_hit
# 0.0     1022
# 1.0     1022
# 2.0     1011
# 3.0     1004
# 6.0      928
# 14.0     671
# 16.0     624
# 18.0     576
# 19.0     555
# 20.0     541
# 21.0     522
# 23.0     489
# 24.0     468
# Name: target, dtype: int64

# %%
for col in cols:
    try:
        df_expt[col + '_diff'] = df_expt.apply(lambda x: np.abs((x[col]/x['target']) - 1), axis=1)
    except ValueError:
        continue

# %%
diff_cols = [col for col in df_expt.columns if 'diff' in col]

# %%
df_expt_sub = df_expt[df_expt['censoring_flg_mod'] == True]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_25175/525252540.py in <cell line: 2>()
#       1 df_expt_sub = df_expt[df_expt['censoring_flg_mod'] == True]
# ----> 2 df_expt_sub.groupby(['weeks_since_hit', 'pred_quintile'])[diff_cols].mean()
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in mean(self, numeric_only)
#    1393         Name: B, dtype: float64
#    1394         """
# -> 1395         return self._cython_agg_general(
#    1396             "mean",
#    1397             alt=lambda x, axis: Series(x).mean(numeric_only=numeric_only),
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/core/groupby/generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1019         self, how: str, alt=None, numeric_only: bool = True, min_count: int = -1
#    1020     ) -> DataFrame:
# -> 1021         agg_blocks, agg_items = self._cython_agg_blocks(
#    1022             how, alt=alt, numeric_only=numeric_only, min_count=min_count
#    1023         )
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/core/groupby/generic.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#    1030         # here, it should happen via BlockManager.combine
#    1031
# -> 1032         data: BlockManager = self._get_data_to_aggregate()
#    1033
#    1034         if numeric_only:
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/core/groupby/generic.py in _get_data_to_aggregate(self)
#    1655
#    1656     def _get_data_to_aggregate(self) -> BlockManager:
# -> 1657         obj = self._obj_with_exclusions
#    1658         if self.axis == 1:
#    1659             return obj.T._mgr
#
# pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/core/base.py in _obj_with_exclusions(self)
#     202     def _obj_with_exclusions(self):
#     203         if self._selection is not None and isinstance(self.obj, ABCDataFrame):
# --> 204             return self.obj.reindex(columns=self._selection_list)
#     205
#     206         if len(self.exclusions) > 0:
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     307         @wraps(func)
#     308         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 309             return func(*args, **kwargs)
#     310
#     311         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/core/frame.py in reindex(self, *args, **kwargs)
#    4034         kwargs.pop("axis", None)
#    4035         kwargs.pop("labels", None)
# -> 4036         return super().reindex(**kwargs)
#    4037
#    4038     def drop(
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    4461
#    4462         # perform the reindex on the axes
# -> 4463         return self._reindex_axes(
#    4464             axes, level, limit, tolerance, method, fill_value, copy
#    4465         ).__finalize__(self, method="reindex")
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/core/frame.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    3874         columns = axes["columns"]
#    3875         if columns is not None:
# -> 3876             frame = frame._reindex_columns(
#    3877                 columns, method, copy, level, fill_value, limit, tolerance
#    3878             )
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/core/frame.py in _reindex_columns(self, new_columns, method, copy, level, fill_value, limit, tolerance)
#    3919             new_columns, method=method, level=level, limit=limit, tolerance=tolerance
#    3920         )
# -> 3921         return self._reindex_with_indexers(
#    3922             {1: [new_columns, indexer]},
#    3923             copy=copy,
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/core/generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4524
#    4525             # TODO: speed up on homogeneous DataFrame objects
# -> 4526             new_data = new_data.reindex_indexer(
#    4527                 index,
#    4528                 indexer,
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate)
#    1283         # some axes don't allow reindexing with dups
#    1284         if not allow_dups:
# -> 1285             self.axes[axis]._can_reindex(indexer)
#    1286
#    1287         if axis >= self.ndim:
#
# ~/PycharmProjects/adds-early-burnout-warning-model/venv/lib/python3.8/site-packages/pandas/core/indexes/base.py in _can_reindex(self, indexer)
#    3290         # trying to reindex on an axis with duplicates
#    3291         if not self.is_unique and len(indexer):
# -> 3292             raise ValueError("cannot reindex from a duplicate axis")
#    3293
#    3294     def reindex(self, target, method=None, level=None, limit=None, tolerance=None):
#
# ValueError: cannot reindex from a duplicate axis

# %%
df_expt_sub.reset_index(inplace=True)

# %%
df_expt_sub.groupby(['weeks_since_hit', 'pred_quintile'])['target'].agg([np.mean, np.median, lambda x: np.percentile(x, 90), lambda x: np.percentile(x, 10)])
# Out:
#                                       mean  median  <lambda_0>  <lambda_1>
# weeks_since_hit pred_quintile
# 0.0             0.0            1740.673611  1751.0      2160.0      1313.3
#                 1.0            1192.594406  1182.0      1453.6       959.0
#                 2.0             838.755245   880.0      1081.8       513.8
#                 3.0             556.041958   554.0       792.6       331.0
#                 4.0             216.006944   188.0       398.1        58.2
# ...                                    ...     ...         ...         ...
# 24.0            0.0             474.114286   366.0      1019.2       141.2
#                 1.0             294.558824   275.5       594.1        41.2
#                 2.0             159.371429    73.0       305.0         9.4
#                 3.0             213.764706   165.5       425.5        17.6
#                 4.0             129.171429    86.0       307.4        19.4
#
# [65 rows x 4 columns]
